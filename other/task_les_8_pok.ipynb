# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
path_to_file = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-d-gazizova/tasks/Pokemon.csv'
pokemon = pd.read_csv(path_to_file)
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# измените названия исходных столбцов:
#    пробелы и точки нужно заменить на "_"
#    приведите все названия к нижнему регистру
#    колонку "#" переименовать в "id"
pokemon = (pokemon.rename(columns={'#' : 'id'})
                  .rename(columns=lambda x: x.replace(' ', '_').replace('.', '').lower()))
pokemon
# Out:
#       id                   name   type_1  type_2  total  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
leg = pokemon.groupby('generation', as_index=False).agg({'legendary':'count'})
leg
# Out:
#    generation  legendary
# 0           1        166
# 1           2        106
# 2           3        160
# 3           4        121
# 4           5        165
# 5           6         82

# %%
#  Cгруппируем данные по поколению покемонов (generation), 
#    и с помощью value_counts() посчитаем, сколько в каком поколении легендарных покемонов (legendary), 
#    а также сколько в этих поколениях нелегендарных покемонов. 
#  Полученный объект приведем к формату датафрейма (.to_frame()) и сохраним в legends.

legends = pokemon.groupby('generation') \
                  .legendary \
                  .value_counts() \
                  .to_frame()
legends
# Out:
#                       legendary
# generation legendary
# 1          False            160
#            True               6
# 2          False            101
#            True               5
# 3          False            142
#            True              18
# 4          False            108
#            True              13
# 5          False            150
#            True              15
# 6          False             74
#            True               8

# %%
# необходимо переименовать колонку legendary в legendary_count

legends = legends.rename(columns={'legendary' : 'legendary_count'})

# %%
#  используем unstack, чтобы поместить уровень индекса legendary в уровень оси столбцов. 
#  Иными словами, должно получиться две колонки – False & True

legends_unstacked = legends.unstack('legendary')
legends_unstacked
# Out:
#            legendary_count
# legendary            False True
# generation
# 1                      160     6
# 2                      101     5
# 3                      142    18
# 4                      108    13
# 5                      150    15
# 6                       74     8

# %%
#   Сгруппируйте датасет pokemon по переменным generation и type_1, 
#   посчитайте количество легендарных покемонов внутри групп. 
#   Приведите данные в формат датафрейма, а затем используйте unstack(). 
#   В качестве ответа выберите вид и поколение покемона, среди которых больше всего легендарных.

pokemon.groupby(['generation', 'type_1']) \
       .legendary.value_counts() \
       .to_frame()
pokemon
# Out:
#       id                   name   type_1  type_2  total  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
gen_unstack = pokemon.groupby(['generation', 'type_1'])  \
                     .legendary.value_counts() \
                     .to_frame().unstack('legendary')
gen_unstack
# Out:
#                     legendary
# legendary               False True
# generation type_1
# 1          Bug           14.0   NaN
#            Dragon         3.0   NaN
#            Electric       8.0   1.0
#            Fairy          2.0   NaN
#            Fighting       7.0   NaN
# ...                       ...   ...
# 6          Poison         2.0   NaN
#            Psychic        3.0   2.0
#            Rock           7.0   2.0
#            Steel          5.0   NaN
#            Water          5.0   NaN
#
# [98 rows x 2 columns]

# %%
#.query("legendary==True")
#.sorted_values('legendary')

leg_max = gen_unstack.loc[:, ('legendary', True)].idxmax()
leg_max
# Out:
# (3, 'Dragon')

# %%
avocado_agg = pd.DataFrame({'type' : ['conventional', 'organic'],
                            'AvgPrice_2015' : [1.077963, 1.673324],
                            'AvgPrice_2016' : [1.105595, 1.571684],
                            'AvgPrice_2017' : [1.294888, 1.735521],
                            'AvgPrice_2018' : [1.127886, 1.567176],
                            })
avocado_agg
# Out:
#            type  AvgPrice_2015  AvgPrice_2016  AvgPrice_2017  AvgPrice_2018
# 0  conventional       1.077963       1.105595       1.294888       1.127886
# 1       organic       1.673324       1.571684       1.735521       1.567176

# %%
avocado_agg_long = pd.wide_to_long(avocado_agg, ['AvgPrice'], i='type', j='year', sep='_')
avocado_agg_long
# Out:
#                    AvgPrice
# type         year
# conventional 2015  1.077963
# organic      2015  1.673324
# conventional 2016  1.105595
# organic      2016  1.571684
# conventional 2017  1.294888
# organic      2017  1.735521
# conventional 2018  1.127886
# organic      2018  1.567176

# %%
path_to_file = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-d-gazizova/tasks/superheroes_power_matrix.csv'
superheroes = pd.read_csv(path_to_file)
superheroes.head()
# Out:
#           Name  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False   False  ...         False            False       False
# ...

# %%
superheroes_long = superheroes.melt(id_vars=['Name'], var_name='superpower')
superheroes_long
# Out:
#                    Name  superpower  value
# 0               3-D Man     Agility   True
# 1                A-Bomb     Agility  False
# 2            Abe Sapien     Agility   True
# 3              Abin Sur     Agility  False
# 4           Abomination     Agility  False
# ...                 ...         ...    ...
# 111384  Yellowjacket II  Omniscient  False
# 111385             Ymir  Omniscient  False
# 111386             Yoda  Omniscient  False
# 111387          Zatanna  Omniscient  False
# 111388             Zoom  Omniscient  False
#
# [111389 rows x 3 columns]

# %%
superheroes_powers = (superheroes_long
                      .query("value==True")
                      .groupby(['Name'], as_index=False)
                      .agg({'superpower': list})         # или .superpower.apply(list) но без as_index=False
                     )
superheroes_powers
# Out:
#                 Name                                         superpower
# 0            3-D Man    [Agility, Super Strength, Stamina, Super Speed]
# 1             A-Bomb  [Accelerated Healing, Durability, Longevity, S...
# 2         Abe Sapien  [Agility, Accelerated Healing, Cold Resistance...
# 3           Abin Sur                               [Lantern Power Ring]
# 4        Abomination  [Accelerated Healing, Intelligence, Super Stre...
# ..               ...                                                ...
# 662  Yellowjacket II             [Flight, Energy Blasts, Size Changing]
# 663             Ymir  [Cold Resistance, Durability, Longevity, Super...
# 664             Yoda  [Agility, Stealth, Danger Sense, Marksmanship,...
# 665          Zatanna  [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 666             Zoom  [Super Speed, Intangibility, Time Travel, Time...
#
# [667 rows x 2 columns]

# %%
path_to_file = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-d-gazizova/tasks/bikes_q1_sample.csv'
bikes_Q1 = pd.read_csv(path_to_file)
bikes_Q1.head()
# Out:
#     trip_id           start_time             end_time  bikeid tripduration  \
# 0  17617135  2018-01-22 20:04:31  2018-01-22 20:11:53    1131        442.0
# 1  17897619  2018-03-16 19:47:59  2018-03-16 20:04:00    6146        961.0
# 2  17881307  2018-03-14 18:49:20  2018-03-14 18:54:38    3847        318.0
# 3  17881130  2018-03-14 18:33:48  2018-03-14 19:07:40    1483      2,032.0
# 4  17686289  2018-02-05 17:39:14  2018-02-05 17:46:13    6391        419.0
#
#    from_station_id           from_station_name  to_station_id  \
# 0              471  Francisco Ave & Foster Ave            468
# 1              296      Broadway & Belmont Ave            253
# 2              260  Kedzie Ave & Milwaukee Ave            503
# 3              199      Wabash Ave & Grand Ave            199
# 4              596      Benson Ave & Church St            605
#
#                to_station_name    usertype  gender  birthyear
# 0        Budlong Woods Library  Subscriber  Female     1949.0
# ...

# %%
bikes_Q1['start_time'] = pd.to_datetime(bikes_Q1['start_time'])

# %%
bikes_Q1.set_index('start_time', inplace = True)
bikes_Q1
# Out:
#                       trip_id             end_time  bikeid tripduration  \
# start_time
# 2018-01-22 20:04:31  17617135  2018-01-22 20:11:53    1131        442.0
# 2018-03-16 19:47:59  17897619  2018-03-16 20:04:00    6146        961.0
# 2018-03-14 18:49:20  17881307  2018-03-14 18:54:38    3847        318.0
# 2018-03-14 18:33:48  17881130  2018-03-14 19:07:40    1483      2,032.0
# 2018-02-05 17:39:14  17686289  2018-02-05 17:46:13    6391        419.0
# ...                       ...                  ...     ...          ...
# 2018-02-28 17:16:53  17792363  2018-02-28 17:18:49    2401        116.0
# 2018-02-08 11:52:44  17695807  2018-02-08 11:58:13    4687        329.0
# 2018-03-22 17:18:21  17938644  2018-03-22 17:24:13    6200        352.0
# 2018-02-20 16:45:07  17738202  2018-02-20 16:57:42     757        755.0
# 2018-01-10 12:08:16  17566765  2018-01-10 12:20:31    4668        735.0
#
#                      from_station_id           from_station_name  \
# start_time
# ...

# %%
bikes_Q1.resample(rule = 'D').size().max()
# Out:
# 4196

# %%
path_to_file = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-d-gazizova/tasks/bikes_april.csv'
bikes_april = pd.read_csv(path_to_file)
bikes_april.head()
# Out:
#             start_time   trip_id             end_time  bikeid tripduration  \
# 0  2018-04-01 00:10:23  18000531  2018-04-01 00:22:12    5065        709.0
# 1  2018-04-01 00:15:49  18000533  2018-04-01 00:19:47    4570        238.0
# 2  2018-04-01 00:17:00  18000534  2018-04-01 00:22:53    1323        353.0
# 3  2018-04-01 00:20:00  18000536  2018-04-01 00:26:22    2602        382.0
# 4  2018-04-01 00:23:19  18000538  2018-04-01 00:35:01    4213        702.0
#
#    from_station_id                from_station_name  to_station_id  \
# 0              228          Damen Ave & Melrose Ave            219
# 1              128          Damen Ave & Chicago Ave            130
# 2              130          Damen Ave & Division St             69
# 3              121  Blackstone Ave & Hyde Park Blvd            351
# 4               31        Franklin St & Chicago Ave            180
#
#                to_station_name    usertype  gender  birthyear
# ...

# %%
bikes_april['start_time'] = pd.to_datetime(bikes_april['start_time'])
bikes_april.set_index('start_time', inplace = True)
bikes_april
# Out:
#                       trip_id             end_time  bikeid tripduration  \
# start_time
# 2018-04-01 00:10:23  18000531  2018-04-01 00:22:12    5065        709.0
# 2018-04-01 00:15:49  18000533  2018-04-01 00:19:47    4570        238.0
# 2018-04-01 00:17:00  18000534  2018-04-01 00:22:53    1323        353.0
# 2018-04-01 00:20:00  18000536  2018-04-01 00:26:22    2602        382.0
# 2018-04-01 00:23:19  18000538  2018-04-01 00:35:01    4213        702.0
# ...                       ...                  ...     ...          ...
# 2018-04-30 23:51:32  18241104  2018-04-30 23:53:50    3529        138.0
# 2018-04-30 23:52:19  18241105  2018-05-01 00:11:53    3274      1,174.0
# 2018-04-30 23:58:00  18241110  2018-05-01 00:25:46    5964      1,666.0
# 2018-04-30 23:58:04  18241111  2018-05-01 00:07:00     331        536.0
# 2018-04-30 23:59:56  18241112  2018-05-01 00:14:17     108        861.0
#
#                      from_station_id                from_station_name  \
# start_time
# ...

# %%
bikes_april = bikes_april.query("usertype=='Subscriber'").resample(rule = 'D').size().loc['2018-04-18']
bikes_april
# Out:
# 2196

# %%
bikes = pd.concat([
           pd.read_csv("/mnt/HC_Volume_18315164/home-jupyter/jupyter-d-gazizova/python_lessons/"), 
           pd.read_csv("data2.csv"), 
           pd.read_csv("data3.csv"), 
           pd.read_csv("data4.csv")
            ])
bikes

# %%
bikes_summer = bikes.loc['2018-06-01':'2018-08-31']

# %%
top_destination = bikes_summer.to_station_name.value_counts().idxmax()

# %%
bad_day = (bikes_summer
           .query("to_station_name==@top_destination")
           .resample('D').size()
           .idxmin()
           .strftime('%Y-%m-%d'))
